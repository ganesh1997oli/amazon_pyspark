# %%
# Check versions
import sys

print("Python version:", sys.version.split()[0])
print("Spark version:", spark.version)

# %%
# Check Spark execution
numbers = spark.range(10)
display(numbers)

# %%
# Find available storage catalogs
spark.sql("SHOW CATALOGS").show(truncate=False)
